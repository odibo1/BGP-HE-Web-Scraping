# %% [markdown]
# <a href="https://colab.research.google.com/github/odibo1/BGP-HE-Web-Scraping/blob/master/CrossYear.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import altair as alt

# %%
df1 = pd.read_csv('TeleGeography Business Broadband All Carrier Postings.csv')
df1
# Out:
#        Quarter  ...                                              Notes
# 0      Q2 2019  ...             3, 6, and 12 month contracts available
# 1      Q2 2019  ...             3, 6, and 12 month contracts available
# 2      Q2 2019  ...             3, 6, and 12 month contracts available
# 3      Q2 2019  ...             3, 6, and 12 month contracts available
# 4      Q2 2019  ...                                                NaN
# ...        ...  ...                                                ...
# 30221  Q2 2016  ...                           1-year service agreement
# 30222  Q2 2016  ...                                                NaN
# 30223  Q2 2016  ...  GVTCI will rent a modem for only $3 mo with a ...
# 30224  Q2 2016  ...  Static IP Address: $5/month ($10 per additiona...
# 30225  Q2 2016  ...  prices based on 1-year contract; required: Cen...
#
# [30226 rows x 25 columns]

# %%
df1['Mbps Down'] = df1['Mbps Down'].str.replace(',',"")

# %%
df1['Mbps Down'] = df1['Mbps Down'].astype(float)

# %%
df2 = pd.read_csv('SO_Canada_200619.csv')
df2
# Out:
#           Region Country      Company  ... Contract Length Created At Updated At
# 0    US & Canada  Canada       Acanac  ...            12.0   6/5/2020   6/5/2020
# 1    US & Canada  Canada      Les.Net  ...             NaN  5/13/2020  5/13/2020
# 2    US & Canada  Canada      Tbaytel  ...             NaN  5/13/2020  6/10/2020
# 3    US & Canada  Canada  CIK Telecom  ...             0.0  5/13/2020   6/8/2020
# 4    US & Canada  Canada    Novus Now  ...             0.0  5/13/2020   6/9/2020
# ..           ...     ...          ...  ...             ...        ...        ...
# 277  US & Canada  Canada  NorthwesTel  ...             NaN  5/13/2020  5/13/2020
# 278  US & Canada  Canada       Ontera  ...             NaN  5/13/2020  6/10/2020
# 279  US & Canada  Canada        Qiniq  ...             0.0  5/13/2020  5/13/2020
# 280  US & Canada  Canada    SSI Micro  ...             0.0  5/13/2020  5/13/2020
# 281  US & Canada  Canada    SSI Micro  ...             0.0  5/13/2020  5/13/2020
#
# [282 rows x 29 columns]

# %%
df2.dtypes
# Out:
# Region                 object
# Country                object
# Company                object
# Tariff Name            object
# Tariff URL             object
# Access Type            object
# Quarter                object
# Mbps Up               float64
# Mbps Down             float64
# GB Allowance          float64
# GB Allowance Notes     object
# Unlimited Data           bool
# NRC USD               float64
# MRC USD               float64
# NRC Local             float64
# MRC Local               int64
# Currency               object
# Exchange Rate         float64
# Technologies           object
# State(s)               object
# Geographic Notes       object
# Notes                  object
# Static IP Notes        object
# Static IP                bool
# 24x7 Support             bool
# Router Included          bool
# Contract Length       float64
# Created At             object
# Updated At             object
# dtype: object

# %%
df2['Mbps Down'] = df2['Mbps Down'].astype(float)

# %%
df3 = pd.concat([df1,df2], axis=0)
df3
# Out:
#      Quarter       Region  Country  ... Exchange Rate Created At Updated At
# 0    Q2 2019       Africa  Algeria  ...           NaN        NaN        NaN
# 1    Q2 2019       Africa  Algeria  ...           NaN        NaN        NaN
# 2    Q2 2019       Africa  Algeria  ...           NaN        NaN        NaN
# 3    Q2 2019       Africa  Algeria  ...           NaN        NaN        NaN
# 4    Q2 2019       Africa  Algeria  ...           NaN        NaN        NaN
# ..       ...          ...      ...  ...           ...        ...        ...
# 277  Q2 2020  US & Canada   Canada  ...      0.750109  5/13/2020  5/13/2020
# 278  Q2 2020  US & Canada   Canada  ...      0.750109  5/13/2020  6/10/2020
# 279  Q2 2020  US & Canada   Canada  ...      0.750109  5/13/2020  5/13/2020
# 280  Q2 2020  US & Canada   Canada  ...      0.750109  5/13/2020  5/13/2020
# 281  Q2 2020  US & Canada   Canada  ...      0.750109  5/13/2020  5/13/2020
#
# [30508 rows x 29 columns]

# %%
df4 = df3[df3['Country'] == 'Canada']
df4
# Out:
#       Quarter       Region Country  ... Exchange Rate Created At Updated At
# 5832  Q2 2019  US & Canada  Canada  ...           NaN        NaN        NaN
# 5833  Q2 2019  US & Canada  Canada  ...           NaN        NaN        NaN
# 5834  Q2 2019  US & Canada  Canada  ...           NaN        NaN        NaN
# 5835  Q2 2019  US & Canada  Canada  ...           NaN        NaN        NaN
# 5836  Q2 2019  US & Canada  Canada  ...           NaN        NaN        NaN
# ...       ...          ...     ...  ...           ...        ...        ...
# 277   Q2 2020  US & Canada  Canada  ...      0.750109  5/13/2020  5/13/2020
# 278   Q2 2020  US & Canada  Canada  ...      0.750109  5/13/2020  6/10/2020
# 279   Q2 2020  US & Canada  Canada  ...      0.750109  5/13/2020  5/13/2020
# 280   Q2 2020  US & Canada  Canada  ...      0.750109  5/13/2020  5/13/2020
# 281   Q2 2020  US & Canada  Canada  ...      0.750109  5/13/2020  5/13/2020
#
# [913 rows x 29 columns]

# %%
df4 = df4.reset_index()
df4
# Out:
#      index  Quarter       Region  ... Exchange Rate Created At Updated At
# 0     5832  Q2 2019  US & Canada  ...           NaN        NaN        NaN
# 1     5833  Q2 2019  US & Canada  ...           NaN        NaN        NaN
# 2     5834  Q2 2019  US & Canada  ...           NaN        NaN        NaN
# 3     5835  Q2 2019  US & Canada  ...           NaN        NaN        NaN
# 4     5836  Q2 2019  US & Canada  ...           NaN        NaN        NaN
# ..     ...      ...          ...  ...           ...        ...        ...
# 908    277  Q2 2020  US & Canada  ...      0.750109  5/13/2020  5/13/2020
# 909    278  Q2 2020  US & Canada  ...      0.750109  5/13/2020  6/10/2020
# 910    279  Q2 2020  US & Canada  ...      0.750109  5/13/2020  5/13/2020
# 911    280  Q2 2020  US & Canada  ...      0.750109  5/13/2020  5/13/2020
# 912    281  Q2 2020  US & Canada  ...      0.750109  5/13/2020  5/13/2020
#
# [913 rows x 30 columns]

# %%
df4 = df4.drop(df4.columns[[0]], 1)
df4
# Out:
#           Region Country  ... Updated At Mbps Down (categories)
# 0    US & Canada  Canada  ...        NaN
# 1    US & Canada  Canada  ...        NaN
# 2    US & Canada  Canada  ...        NaN
# 3    US & Canada  Canada  ...        NaN
# 4    US & Canada  Canada  ...        NaN
# ..           ...     ...  ...        ...                    ...
# 908  US & Canada  Canada  ...  5/13/2020
# 909  US & Canada  Canada  ...  6/10/2020
# 910  US & Canada  Canada  ...  5/13/2020
# 911  US & Canada  Canada  ...  5/13/2020
# 912  US & Canada  Canada  ...  5/13/2020
#
# [913 rows x 29 columns]

# %%
df4['Mbps Down'] = df4['Mbps Down'].astype(float)

# %%
categories = ['0-25','26-50','51-100','101-150','151-250','251-500','>500']

df4['Mbps Down (categories)'] = ''

for i in df4.index:
    if df4.at[i, 'Mbps Down'] < 26:
        df4.at[i, 'Mbps Down (categories)'] = categories[0]
    
    elif df4.at[i, 'Mbps Down'] > 25 and df4.at[i, 'Mbps Down'] < 51:
        df4.at[i, 'Mbps Down (categories)'] = categories[1]
    
    elif df4.at[i, 'Mbps Down'] > 50 and df4.at[i, 'Mbps Down'] < 101:
        df4.at[i, 'Mbps Down (categories)'] = categories[2]
    
    elif df4.at[i, 'Mbps Down'] > 100 and df4.at[i, 'Mbps Down'] < 151:
        df4.at[i, 'Mbps Down (categories)'] = categories[3]
    
    elif df4.at[i, 'Mbps Down'] > 150 and df4.at[i, 'Mbps Down'] < 251:
        df4.at[i, 'Mbps Down (categories)'] = categories[4]
    
    elif df4.at[i, 'Mbps Down'] > 250 and df4.at[i, 'Mbps Down'] < 501:
        df4.at[i, 'Mbps Down (categories)'] = categories[5]
    
    elif df4.at[i, 'Mbps Down'] > 500:
        df4.at[i, 'Mbps Down (categories)'] = categories[6]

df4[['Mbps Down','Mbps Down (categories)']].sample(10)
# Out:
#      Mbps Down Mbps Down (categories)
# 206       15.0                   0-25
# 883        7.0                   0-25
# 57       150.0                101-150
# 281      940.0                   >500
# 494       25.0                   0-25
# 7        940.0                   >500
# 482       40.0                  26-50
# 738      100.0                 51-100
# 899        5.0                   0-25
# 396       10.0                   0-25

# %%
df4[['Mbps Down','Mbps Down (categories)']].sample(10)
# Out:
#      Mbps Down Mbps Down (categories)
# 419        5.0                   0-25
# 373       20.0                   0-25
# 131       50.0                  26-50
# 579       60.0                 51-100
# 287      300.0                251-500
# 401       10.0                   0-25
# 319      100.0                 51-100
# 718      120.0                101-150
# 286      300.0                251-500
# 702      150.0                101-150

# %%
df4[df4['Mbps Down'].isna()]
# Out:
# Empty DataFrame
# Columns: [Region, Country, Company, Tariff Name, Tariff URL, Mbps Down, Mbps Up, Access Type, Technologies, State(s), Geographic Notes, GB Allowance, Unlimited Data, Static IP, Static IP Notes, 24x7 Support, Router Included, Contract Length, Currency, NRC Local, MRC Local, NRC USD, MRC USD, Notes, GB Allowance Notes, Exchange Rate, Created At, Updated At, Mbps Down (categories)]
# Index: []
